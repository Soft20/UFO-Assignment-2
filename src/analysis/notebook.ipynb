# %% [markdown]
# # Performance Analyser

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

pd.options.display.float_format = '{:.4f}'.format

# %% [markdown]
# ## Load Data

# %%
observations = pd.read_csv(r'observations.csv', header=None)
observations = observations.T
observations.columns = observations.iloc[0]
observations = observations[1:]
observations.head()
# Out:
# 0 Tally_Chars Tally_Chars_Custom_1 Tally_Chars_Custom_2 Tally_Chars_Custom_3
# 1   289340845             74401779             64283428             53715598
# 2   193198271             54223713             38983320             33539976
# 3   108455308             48799938             28766893             25451832
# 4   139569041             50962472             29432161             24885887
# 5   125388129             53416814             28124096             29139733

# %% [markdown]
# ## Box Plots

# %%
for (columnName, columnData) in observations.iteritems():
    figure = plt.figure()
    plt.boxplot(columnData.values)
    plt.show()

    figure.savefig(f'{columnName}.png')

# %% [markdown]
# ## Descriptive Statistics

# %%
observations.std()
# Out:
# 0
# Tally_Chars            44704672.3019
# Tally_Chars_Custom_1    5212312.7555
# Tally_Chars_Custom_2    5884498.2695
# Tally_Chars_Custom_3    4698149.1470
# dtype: float64

# %%
observations.mean()
# Out:
# 0
# Tally_Chars            77245155.5800
# Tally_Chars_Custom_1   50741955.4000
# Tally_Chars_Custom_2   30583595.9400
# Tally_Chars_Custom_3   26328980.2800
# dtype: float64
